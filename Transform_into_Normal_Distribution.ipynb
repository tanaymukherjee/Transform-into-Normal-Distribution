# %% [markdown]
# <a href="https://colab.research.google.com/github/tanaymukherjee/Transform-into-Normal-Distribution/blob/master/Transform_into_Normal_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Packages and libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Plot Exponential and weibull distributions

# %%
plt.figure(figsize = (10,4), dpi = 120)

#Plotting exponential distribution
plt.subplot(121)
plt.hist(X, bins = 100)
plt.title("exponential distribution")

#plotting weibull distribution
plt.subplot(122)
plt.hist(Y, bins = 100)
plt.title("weibull distribution")
# Out:
# Text(0.5, 1.0, 'weibull distribution')

# %% [markdown]
# #### Plot Exponential and Log Normal distributions

# %%
#Exponential distribution
X = np.random.exponential(2, (10000,1))

#Log Normal distribution
Y = np.random.weibull(a = 2, size = (10000,1))

# %%
from sklearn.preprocessing import QuantileTransformer
qt = QuantileTransformer(n_quantiles = len(X), output_distribution = 'normal')

## transforming above distributions to Normal distribution ##
X = qt.fit_transform(X)
Y = qt.fit_transform(Y)
print('distributions transformed')
# Out:
# distributions transformed

# %% [markdown]
# #### Plot transformed distributions

# %%
plt.figure(figsize = (10,4), dpi = 120)

#Plotting transformed exponential
plt.subplot(121)
plt.hist(X, bins = 100)
plt.title("transformed exponential")

#plotting transformed weibull
plt.subplot(122)
plt.hist(Y, bins = 100)
plt.title("transformed weibull")
# Out:
# Text(0.5, 1.0, 'transformed weibull')
